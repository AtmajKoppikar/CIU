# %%
# !pip3 install -U selenium
# !pip3 install webdriver-manager
# !apt-get update
# !apt install chromium-chromedriver
# Out:
# ...
# zsh:1: command not found: apt-get
# The operation couldn’t be completed. Unable to locate a Java Runtime that supports apt.
# Please visit http://www.java.com for information on installing Java.

# %%
import selenium
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
import platform
from time import sleep
import csv

os = platform.platform()
driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()))
driver.get("https://web.whatsapp.com")
# Out:
# [WDM] - ====== WebDriver manager ======
# [WDM] - Current google-chrome version is 103.0.5060
# [WDM] - Get LATEST chromedriver version for 103.0.5060 google-chrome
# [WDM] - Driver [/Users/atmajkoppikar/.wdm/drivers/chromedriver/mac64_m1/103.0.5060.53/chromedriver] found in cache

# %% [markdown]
# # Scan the QR code and after your chats are visible, press 'enter' here

# %%
input('If the chats are visible, press Enter')
# Out:
# If the chats are visible, press Enter
# ''

# %%
excel_data = []
with open('Registrations CIU.csv', 'r') as csvfile:
    # creating a csv reader object
    csvreader = csv.reader(csvfile)
     
    # extracting field names through first row
    fields = next(csvreader)
 
    # extracting each data row one by one
    for row in csvreader:
        excel_data.append(row)
sent_list = []
failed_list = []
count = -1

# %%
excel_data
# Out:
# [['7021129874'], ['7977623387']]

# %%
for n in excel_data:
    count = count + 1
    #num = str(excel_data['Contact'][count])
    num = str(n[0])
    if len(num) != 10:
        print(num + "Is not a correct number")
        continue
    if num in sent_list:
        continue
    try:
        url = 'https://web.whatsapp.com/send?phone=+91' + num + '&text=' + text
        driver.get(url)
        sleep(6)
        driver.find_element(By.XPATH,"/html/body/div[1]/div/div/div[4]/div/footer/div[1]/div/span[2]/div/div[2]/div[2]/button/span").click()
    except Exception as e:
        print("Cannot send to "+num)
        print(e)
    sleep(8)

# %%
text_box = driver.find_element(By.CLASS_NAME,"p3_M1")
text_box
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="126baafeea094db7851f2e2412da21dc", element="f99dba2a-3e6a-45b2-b105-8660685d8a1b")>

# %%
if 'mac' in os:
    text_box.send_keys(Keys.COMMAND + "v")
else:
    text_box.send_keys(Keys.CONTROL + "v")
text_box.send_keys(Keys.ENTER)

# %%
driver.close()

# %%
text = 'Change Is Us is celebrating their 100 weeks of Beach Clean ups✨\nChange is us is a youth-led initiative focused on environmental conservation and tackling plastic pollution. We have removed around 170 tonnes of waste from the waters in our 99 weeks of operation since July, 2019.🚀\nWe are now heading towards our 100th week of weekly beach clean ups at Girgaon Chowpatty and wish for you to be a part of this!🤝\n"Be the change you want to see in the world!!" 🌱\nJoin us and become a part of the movement.🌍\nDate🗓️ : 3rd July, 2022\nLocation 📍: Girgaon Chowpatty Beach\nTime 🕖: 7:30am - 9:30am\nRegistration Link 🔗: https://forms.gle/RwzSYma8j9jHiUJS7\nCertificates will be provided to those who come for the clean up\nInstagram Handle : https://instagram.com/change.is.us?igshid=YmMyMTA2M2Y=\n(Follow for more updates)\nWe hope to see you there! 🌟'
